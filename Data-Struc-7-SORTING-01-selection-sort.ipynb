# %% [markdown]
# # Selection Sort
#
# - The selection sort improves on the bubble sort by making only 1 exchange for every pass through the list.
#
# - In order to do this, a selection sort looks for the largest value as it makes a pass and after completing the pass, places it in the proper location.
#
# - As with a bubble sort, after the first pass, the largest item is in the correct place.
#
# - After the second pass, the next largest is in place. This process continues and requires n−1 passes to sort n items, since the final item must be in place after the (n−1)th pass.
#
# ![selection-sort1.GIF](attachment:selection-sort1.GIF)

# %%
alist = [54, 26, 93, 17, 77, 31, 44, 55, 20]

# %%
def selectionSort(myList):

    for i in range(0, len(myList)):
        
        # find the min value in the list 
        min_val       = min(myList[i: len(myList)])
        min_val_index = myList.index(min_val)
          
        myList[i], myList[min_val_index] = myList[min_val_index], myList[i]
        
    return myList

# %%
selectionSort(alist)
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %%
alist
# Out:
# [17, 20, 26, 31, 44, 54, 55, 77, 93]

# %% [markdown]
# - does this actucally improve upon bubble sort? If no then what should be done?
#
#
# You may see that the selection sort makes the same number of comparisons as the bubble sort and is therefore also O($n^2$).
#
# However, due to the reduction in the number of exchanges, the selection sort typically executes faster in benchmark studies
#
#
# __Q-1__: Suppose you have the following list of numbers to sort: [11, 7, 12, 14, 19, 1, 6, 18, 8, 20] which list represents the partially sorted list after three complete passes of selection sort?
#
#     (A) [7, 11, 12, 1, 6, 14, 8, 18, 19, 20]
#     (B) [7, 11, 12, 14, 19, 1, 6, 18, 8, 20]
#     (C) [11, 7, 12, 14, 1, 6, 8, 18, 19, 20]
#     (D) [11, 7, 12, 14, 8, 1, 6, 18, 19, 20]
