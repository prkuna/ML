# %% [markdown]
# Recursion is a method of solving problems that involves breaking a problem down into smaller and smaller subproblems until you get to a small enough problem that it can be solved trivially.
#
# Usually recursion involves a function calling itself. While it may not seem like much on the surface, recursion allows us to write elegant solutions to problems that may otherwise be very difficult to program.
#
# ### Calculating the Sum of a List of Numbers

# %%
def listsum(numList):
    theSum = 0
    for i in numList:
        theSum = theSum + i
    return theSum

# %%
print(listsum([1,3,5,7,9]))
# Out:
# 25

# %% [markdown]
# Pretend for a minute that you do not have while loops or for loops. How would you compute the sum of a list of numbers?

# %%
def listsum(numList):
    if len(numList) == 1:
        return numList[0]
    else:
        return numList[0] + listsum(numList[1:])

# %%
print(listsum([1,3,5,7,9]))
# Out:
# 25

# %% [markdown]
# series of recursive calls that are needed to sum the list [1,3,5,7,9]
# ![recur1.GIF](attachment:recur1.GIF)
#
# When we reach the point where the problem is as simple as it can get, we begin to piece together the solutions of each of the small problems until the initial problem is solved. Figure 2 shows the additions that are performed as listsum works its way backward through the series of calls. When listsum returns from the topmost problem, we have the solution to the whole problem.
#
# ![recur2.GIF](attachment:recur2.GIF)

# %% [markdown]
# Q-1: How many recursive calls are made when computing the sum of the list [2,4,6,8,10]?
#
#     (A) 6
#     (B) 5
#     (C) 4
#     (D) 3

# %% [markdown]
# Ans : 4
#
# Correct! the first recursive call passes the list [4,6,8,10], the second [6,8,10] and so on until [10].
#
# First call is NOT a recursive call

# %% [markdown]
# Q-2: Suppose you are going to write a recusive function to calculate the factorial of a number. fact(n) returns n * n-1 * n-2 * ... Where the factorial of zero is definded to be 1. What would be the most appropriate base case?
#
#     (A) n == 0
#     (B) n == 1
#     (C) n >= 0
#     (D) n <= 1
#
#     A - incorrect , Although this would work there are better and slightly more efficient choices. since fact(1) and fact(0) are the same.
#
#     D - Correct! Good, this is the most efficient, and even keeps your program from crashing if you try to compute the factorial of a negative number.
