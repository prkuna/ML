# %% [markdown]
# # Binary Tree
#
# A binary tree is a tree data structure in which each parent node can have at most two children
#
# ![tree%60.GIF](attachment:tree%60.GIF)
#
# each element has at most two children.
#
# # Full Binary Tree
#
# A full Binary tree is a special type of binary tree in which every parent node has either two or no children. So you have no nodes with only 1 child.
#
# ![tree1.GIF](attachment:tree1.GIF)
# ![tree5.GIF](attachment:tree5.GIF)
#
# # Complete binary tree
#
# A complete binary tree is just like a full binary tree, but with two major differences
#
#     A complete binary tree is a binary tree in which every level, except possibly the last, is completely filled, and all nodes are as far left as possible.
#
#     All the leaf elements must lean towards the left.
#
#     The last leaf element might not have a right sibling i.e. a complete binary tree doesn’t have to be a full binary tree.
#
# ![tree3.GIF](attachment:tree3.GIF)
#
# ![tree4.GIF](attachment:tree4.GIF)
#
# ![tree6.GIF](attachment:tree6.GIF)

# %% [markdown]
# # How to create a complete binary tree from an unsorted list (array)?
#     Select first element of the list to be the root node. (First level - 1 element)
#
#     Put the second element as a left child of the root node and the third element as a right child. (Second level - 2 elements)
#
#     Put next two elements as children of left node of second level. Again, put the next two elements as children of right node of second level (3rd level - 4 elements).
#
#     Keep repeating till you reach the last element.
#
#  ![tree7.GIF](attachment:tree7.GIF)

# %% [markdown]
# # Relationship between array indexes and tree elements
# Complete binary tree has an interesting property that we can use to find the children and parents of any node.
#
# If the index of any element in the array is i, the element in the index 2i+1 will become the left child and element in 2i+2 index will become the right child. Also, the parent of any element at index i is given by the lower bound of (i-1)/2.
#
# ![tree8.GIF](attachment:tree8.GIF)
#
# Let’s test it out,
#
#     Left child of 1 (index 0)
#     = element in (2*0+1) index
#     = element in 1 index
#     = 12
#
#
#     Right child of 1
#     = element in (2*0+2) index
#     = element in 2 index
#     = 9
#
# Similarly,
#
#     Left child of 12 (index 1)
#     = element in (2*1+1) index
#     = element in 3 index
#     = 5
#
#     Right child of 12
#     = element in (2*1+2) index
#     = element in 4 index
#     = 6
#
# Let us also confirm that the rules holds for finding parent of any node
#
#     Parent of 9 (position 2)
#     = (2-1)/2
#     = ½
#     = 0.5
#     ~ 0 index
#     = 1
#
#     Parent of 12 (position 1)
#     = (1-1)/2
#     = 0 index
#     = 1
